# %%
import csv
from operator import itemgetter
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import numpy as np
import datetime
import pandas as pd

from tashu_bonus import *

# %%
class Go():
    def __init__(self):
        self.tashu_file = open('tashu.csv','r')
        self.station_file = open('station.csv','r')
        self.tashu_dict = csv.DictReader(self.tashu_file)
        self.station_dict = csv.DictReader(self.station_file)
    def show_get_num_region(self):
        result = get_num_region(self.tashu_dict, self.station_dict)
        pass
    def show_get_station_per_region(self):
        result = get_station_per_region(self.tashu_dict, self.station_dict)
        pass
    def show_get_num_by_day(self):
        result = get_num_by_day(self.tashu_dict, self.station_dict)
        pass
    def show_get_num_by_time(self):
        result = get_num_by_time(self.tashu_dict, self.station_dict)
        pass

# %%
Go().show_get_num_region()

# %%
Go().show_get_station_per_region()

# %%
Go().show_get_num_by_day()

# %%
Go().show_get_num_by_time()
